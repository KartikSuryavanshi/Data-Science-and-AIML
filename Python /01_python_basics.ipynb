# %%
a = 5

# %%
b = 34

# %%
a
# Out:
# 5

# %%
a+b
# Out:
# 39

# %%
name = "Kartik"

# %%
print ("Hello world ")# this will primnt hello world
# Out:
# Hello world

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %% [raw]
# print(type(name))

# %%
name = "Kartik"
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a ="45555'
# Out:
#   Cell In[13], line 1
#     a ="45555'
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a="455"

# %%
b ="444"

# %%
a+b#concatenate
# Out:
# '455444'

# %%
int(a) + int(b)# type casting
# Out:
# 899
