# %%
name = "kartik"

# %%
name
# Out:
# 'kartik'

# %%
name.upper()
# Out:
# 'KARTIK'

# %%
name.endswith("ik")
# Out:
# True

# %%
name.lower()
# Out:
# 'kartik'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("k")
# Out:
# 2

# %%
len(name)
# Out:
# 6

# %%
name.strip()
# Out:
# 'kartik'

# %%
name.replace("kartik","hero")
# Out:
# 'hero'

# %%
name.split()# converts into list
# Out:
# ['kartik']

# %%
name[0:5]#string slicing
# Out:
# 'karti'

# %%
name[1:-1]
# Out:
# 'arti'

# %%
name[0:6]
# Out:
# 'kartik'
