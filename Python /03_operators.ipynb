# %%
a=7
b=6

# %%
a+b
# Out:
# 13

# %%
a-b
# Out:
# 1

# %%
a*b
# Out:
# 42

# %%
a/b
# Out:
# 1.1666666666666667

# %%
a//b #floor division no no. after point
# Out:
# 1

# %%
a%b# remainder
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
a**b
# Out:
# 117649

# %%
a=55

# %%
b=4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
c=9

# %%
a==c #is a equal to c?
# Out:
# False

# %%
a !=c
# Out:
# True

# %%
a=7
b=7

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
b1= True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2 #any one is true -- or
# Out:
# True

# %%
b1 and b2 #both should be true --and
# Out:
# False

# %%
a=45

# %%
a+=6

# %%
a
# Out:
# 51

# %%
a-=9

# %%
a
# Out:
# 42

# %%
a
# Out:
# 33

# %%
a**=9

# %%
a
# Out:
# 46411484401953

# %%
11//2
# Out:
# 5

# %%
a//=2

# %%
a
# Out:
# 23205742200976

# %%
a=11

# %%
a//=2

# %%
a
# Out:
# 5
