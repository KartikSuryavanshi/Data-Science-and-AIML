# %%
a = input("Enter value of a")# by deafult it takes user input as string
# Out:
# Enter value of a 34

# %%
a
# Out:
# '34'

# %%
b = input("enter value of b " )
# Out:
# enter value of b  33

# %%
b
# Out:
# '33'

# %%
a+b
# Out:
# '3433'

# %%
int(a)+int(b)
# Out:
# 67

# %%
c = input()
# Out:
#  44

# %%
c
# Out:
# '44'
