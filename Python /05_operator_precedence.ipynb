# %%
result = 10+2*3

# %%
result
# Out:
# 16

# %%
54*3/23+4-2**5  #  *,/,+,-  :left to right(lower precedence)   and **  :right to left----order of evaluation (higher precedence)
# Out:
# -20.956521739130434
