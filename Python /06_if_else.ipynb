# %%
# if , if-else , if-elif-else

# %%
a=3000
if (a>87):
    print("greater")
else:
    print("sammer")
# Out:
# greater

# %%
a=41
if (a>87):
    print("greater")
elif (a>40):
    print("greater than 40")
elif(a>90):
    print("sammer")
else:
    print("sammer")
# Out:
# greater than 40

# %%
def avg(a,b=10):
    return (a+b)/2

# %%
avg(6,6)
# Out:
# 6.0

# %%
avg(4)
# Out:
# 7.0

# %%
def greet():
    print("good morning")

# %%
greet()
# Out:
# good morning

# %%
None # reserved keyword in python
