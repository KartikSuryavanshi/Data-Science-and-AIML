# %%
l=[3,5,23,44]# list is ordered,mutable collection of elements ie it can be changes

# %%
l[1]
# Out:
# 5

# %%
l[0]=4

# %%
l
# Out:
# [4, 5, 23, 44]

# %%
#methods of lists modifies the list ie it modifies original list

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 44, 9]

# %%
l2=[5,7]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 44, 9, 5, 7]

# %%
l.insert(1,100) # insert 200 at index 1

# %%
l
# Out:
# [4, 100, 200, 200, 5, 23, 44, 9, 5, 7]

# %%
number =l.pop(4)

# %%
l
# Out:
# [4, 100, 200, 200, 44, 9, 5, 7]

# %%
number
# Out:
# 23

# %%
l
# Out:
# [4, 100, 200, 200, 44, 9, 5, 7]

# %%
l.index(4)
# Out:
# 0

# %%
l.index(200)
# Out:
# 2

# %%
l.count(200)
# Out:
# 2

# %%
l.sort()

# %%
l
# Out:
# [4, 5, 7, 9, 44, 100, 200, 200]

# %%
sorted(l)# changes and sorts the original list in ascending order
# Out:
# [4, 5, 7, 9, 44, 100, 200, 200]

# %%
newl =[2,6,1,21,6]

# %%
sorted(newl)# returns a new list which is sorted version of original list
# Out:
# [1, 2, 6, 6, 21]

# %%
newl
# Out:
# [2, 6, 1, 21, 6]

# %%
y = [1,2, True, False,[4,5]]

# %%
y
# Out:
# [1, 2, True, False, [4, 5]]

# %%
y[4]
# Out:
# [4, 5]

# %%
y[4][0]
# Out:
# 4

# %%
y[4][1]
# Out:
# 5

# %%
list1=[4,5,89]

# %%
list2=[90,44,2]

# %%
list1+list2
# Out:
# [4, 5, 89, 90, 44, 2]

# %%
list1
# Out:
# [4, 5, 89]

# %%
list2
# Out:
# [90, 44, 2]

# %%
if 3 in list2:
    print("yes")

# %%
3 in list2
# Out:
# False

# %%
5 in list1
# Out:
# True

# %%
s="jack-jill-shubham-kirti-javed-akshay"

# %%
s.split("-")#it returns a list ie called splitting a string into list
# Out:
# ['jack', 'jill', 'shubham', 'kirti', 'javed', 'akshay']
