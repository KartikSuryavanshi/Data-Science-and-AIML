# %%
#tuple is ordered, immutable collection of elements it is similar to list just cant be modifies

# %%
e=()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
t =(2,33,89,78,2)

# %%
len(t)
# Out:
# 5

# %%
t[1]
# Out:
# 33

# %%
t[0]
# Out:
# 2

# %%
t[1]=33# as we know tuple cannot be changes this is the reason we use tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t[1]=33
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Packing
person = ("Alice", 25, "Engineer")
 
# Unpacking
name, age, profession = person

# %%
name
# Out:
# 'Alice'

# %%
age
# Out:
# 25

# %%
profession
# Out:
# 'Engineer'

# %%
t.count(2)
# Out:
# 2
