# %%
# A dictionary in Python is an unordered, mutable, and key-value pair collection.
#It allows efficient data retrieval and modification. Dictionaries in Python are ordered as of Python 3.7

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
student["name"]
# Out:
# 'Alice'

# %%
student["age"]
# Out:
# 25

# %%
student["name2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 student["name2"]
#
# KeyError: 'name2'

# %%
student.get("name")# .get(key,default) method that returns default if key doesnt exist(doesnot modify the dict)
# Out:
# 'Alice'

# %%
r =student.get("name3")

# %%
print(r)
# Out:
# None

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"] =43

# %%
print(student)
# Out:
# {'name': 'Alice', 'age': 43, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 43, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 43), ('grade', 'A')])

# %%
student.update({"name":"harry"})

# %%
student
# Out:
# {'name': 'harry', 'age': 43, 'grade': 'A'}

# %%
student.update({"name":"don", "language":"python"})

# %%
student
# Out:
# {'name': 'don', 'age': 43, 'grade': 'A', 'language': 'python'}

# %%
student.pop("grade")
# Out:
# 'A'

# %%
student
# Out:
# {'name': 'don', 'age': 43, 'language': 'python'}

# %%
student.popitem()
# Out:
# ('language', 'python')

# %%
student
# Out:
# {'name': 'don', 'age': 43}

# %%
student.setdefault("city", "Unknown")
# Out:
# 'Unknown'

# %%
student
# Out:
# {'name': 'don', 'age': 43, 'city': 'Unknown'}

# %%
# Creating a dictionary using comprehension
squares = {x: x**2 for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
