# %%
f = open("text.txt", "r")

# %%
f.read()
# Out:
# '\nis\ngood\nboy'

# %%
s ="this is right way to learn data science"

# %%
f.close()

# %%
f = open ("kartik.txt","w")

# %%
f.write(s)
# Out:
# 39

# %%
f.close()

# %%
with open("text.txt", "r") as file:
    content = file.read()
    print(content)  # No need to manually close the file
# Out:
# kartik suryavanshi
# is
# good
# boy

# %%
file = open("text.txt", "a")
file.write("\nThis is an additional line.")
file.close()

# %%
import os

if os.path.exists("text.txt"):
    print("File exists!")
else:
    print("File not found!")
# Out:
# File exists!

# %%
import os

if os.path.exists("example.txt"):
    print("File exists!")
else:
    print("File not found!")
# Out:
# File not found!

# %%
import os

if os.path.exists("example.txt"):
    os.remove("example.txt")
    print("File deleted.")
else:
    print("File does not exist.")
# Out:
# File does not exist.
