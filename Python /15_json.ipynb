# %%
import json

# %%
obj={"name":"kartik" , "company" : "Google", "salary": 45000000}
s =json.dumps(obj)  #Convert Python object to JSON string
type(s)
print(s)
# Out:
# {"name": "kartik", "company": "Google", "salary": 45000000}

# %%
d= json.loads ('{"name":"kartik" , "company" : "Google", "salary": 45000000}') # Convert JSON string to Python object

# %%
type(d)
# Out:
# dict

# %%
file =open("data.json","w")

# %%
json.dump(obj, file)

# %%
file.close()

# %%
#json.dump() – Write JSON data to a file
#json.load() – Read JSON data from a file

# %%
formatted_json = json.dumps(obj, indent=4)
print(formatted_json)
# Out:
# {
#     "name": "kartik",
#     "company": "Google",
#     "salary": 45000000
# }
